# %% [markdown]
# # Digital Signal Processing
#
# ### MsCV - ViBOT - MAIA

# %%
# %matplotlib inline
# %pprint off

# To make some nice plot
import matplotlib.pyplot as plt
# To play with arrays
import numpy as np
import scipy as sp
from skimage import io

from skimage import img_as_float
from matplotlib import cm
from skimage import img_as_ubyte
from scipy import signal
# Out:
# Pretty printing has been turned ON
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-a4120b048168> in <module>()
#      12 from matplotlib import cm
#      13 from skimage import img_as_ubyte
# ---> 14 from scipy import signal, cheby
#      15
#
# ImportError: cannot import name cheby

# %% [markdown]
# ## Filtering
# **1.1**

# %%
##butterwoth order 3 for low pass


b, a = signal.butter(3, 0.1,'low') ##order 3
w, h = signal.freqs(b, a) ##continous, freqz for discrete
plt.plot(w, 20 * np.log10(abs(h)))
plt.xscale('log')
plt.title('Butterworth low pass filter')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()


##butterwoth order 3 for high pass
b, a = signal.butter(3, 0.1,'high', analog=True) ##order 3
w, h = signal.freqs(b, a) ##continous, freqz for discrete
plt.plot(w, 20 * np.log10(abs(h)))
plt.xscale('log')
plt.title('Butterworth highpass filter')
plt.xlabel('Normalised frequency')
plt.ylabel('gain')
plt.margins(0, 0.1)
# plt.grid(which='both', axis='both')
# plt.axvline(100, color='green') # cutoff frequency
plt.show()


##butterwoth order 3 for bandpass
b, a = signal.butter(3, [0.1,0.2],'bandpass', analog=True) ##order 3
w, h = signal.freqs(b, a) ##continous, freqz for discrete
plt.plot(w, 20 * np.log10(abs(h)))
plt.xscale('log')
plt.title('Butterworth banspass filter')
plt.xlabel('Normalised frequency')
plt.ylabel('gain')
plt.margins(0, 0.2)
# plt.grid(which='both', axis='both')
# plt.axvline(100, color='green') # cutoff frequency
plt.show()

##butterwoth order 3 for bandstop

b, a = signal.butter(3, [0.1,0.2],'bandstop', analog=True) ##order 3
w, h = signal.freqs(b, a) ##continous, freqz for discrete
plt.plot(w, np.log10(abs(h)))
plt.xscale('log')
plt.title('Butterworth bandstop filter')
plt.xlabel('Normalised frequency')
plt.ylabel('gain')
plt.margins(0, 0.2)
# plt.grid(which='both', axis='both')
# plt.axvline(100, color='green') # cutoff frequency
plt.show()

# %%
##cheby order 3 for low pass


b, a = signal.cheby1(3,1, 0.1,'low', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby low pass filter')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()


##cheby order 3 for high pass


b, a = signal.cheby1(3,1, 0.1,'high', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby high pass filter')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()


##cheby order 3 for bandpass 
b, a = signal.cheby1(3,1, [0.01,0.1],'bandpass', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby bandpass pass filter')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()


##cheby order 3 for bandstop 
b, a = signal.cheby1(3,1, [0.01,0.1],'bandstop', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby bandstop pass filter')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()

# ##butterwoth order 3 for high pass
# b, a = signal.cheby(3, 0.1,'high', analog=True) ##order 3
# w, h = signal.freqs(b, a) ##continous, freqz for discrete
# plt.plot(w/np.pi, 20 * np.log10(abs(h)))
# plt.xscale('log')
# plt.title('Butterworth highpass filter')
# plt.xlabel('Normalised frequency')
# plt.ylabel('gain')
# plt.margins(0, 0.1)
# # plt.grid(which='both', axis='both')
# # plt.axvline(100, color='green') # cutoff frequency
# plt.show()

# %%
##cheby order 3 for lowpass
b, a = signal.cheby1(3,1, 0.5,'low', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby low pass filterwith order 3')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()




##cheby order 3 for lowpass
b, a = signal.cheby1(5,1, 0.5,'low', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby low pass filterwith order 5')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()


##cheby order 3 for lowpass
b, a = signal.cheby1(10,1, 0.5,'low', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby low pass filterwith order 10')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()

##cheby order 3 for lowpass
b, a = signal.cheby1(14,1, 0.5,'low', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby low pass filterwith order 14')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()


##cheby order 3 for lowpass
b, a = signal.cheby1(20,1, 0.5,'low', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby low pass filterwith order 20')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()

# %%
##cheby2 order 3 for lowpass
b, a = signal.cheby2(3,1, 0.5,'low', analog=False) ##order 3
w, h = signal.freqz(b, a) ##continous, freqz for discrete
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title(' cheby2 low pass filterwith order 3')
plt.xlabel('Normalised frequency')
plt.ylabel('Gain')
plt.margins(0, 0.2)
#plt.grid(which='both', axis='both')
##plt.axvline(100, color='green') # cutoff frequency
plt.show()

#ellip
b, a = signal.ellip(3, 5, 40, 100, 'low', analog=True)
w, h = signal.freqs(b, a)
plt.semilogx(w, 20 * np.log10(abs(h)))
plt.title('Elliptic low pass filter frequency response (rp=5, rs=40)')
plt.xlabel('Normalised Frequency')
plt.ylabel('Gain')
plt.margins(0, 0.1)

plt.show()

# %% [markdown]
# **1.2**

# %%
from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y


def run():
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.signal import freqz

    # Sample rate and desired cutoff frequencies (in Hz).
    fs = 5000.0
    lowcut = 500.0
    highcut = 1250.0

    # Plot the frequency response for a few different orders.
    plt.figure(1)
    plt.clf()
    for order in [3, 6, 9]:
        b, a = butter_bandpass(lowcut, highcut, fs, order=order)
        w, h = freqz(b, a, worN=2000)
        plt.plot((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)

    plt.plot([0, 0.5 * fs], [np.sqrt(0.5), np.sqrt(0.5)],
             '--', label='sqrt(0.5)')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')

    # Filter a noisy signal.
    T = 0.05
    nsamples = T * fs
    t = np.linspace(0, T, nsamples, endpoint=False)
    a = 0.02
    f0 = 600.0
    x = 0.1 * np.sin(2 * np.pi * 1.2 * np.sqrt(t))
    x += 0.01 * np.cos(2 * np.pi * 312 * t + 0.1)
    x += a * np.cos(2 * np.pi * f0 * t + .11)
    x += 0.03 * np.cos(2 * np.pi * 2000 * t)
    plt.figure(2)
    plt.clf()
    plt.plot(t, x, label='Noisy signal')

    y = butter_bandpass_filter(x, lowcut, highcut, fs, order=6)
    plt.plot(t, y, label='Filtered signal (%g Hz)' % f0)
    plt.xlabel('time (seconds)')
    plt.hlines([-a, a], 0, T, linestyles='--')
    plt.grid(True)
    plt.axis('tight')
    plt.legend(loc='upper left')

    plt.show()
run()

# %% [markdown]
# ## Recursive filter
#
# **2.1**

# %% [markdown]
# **2.2**

# %% [markdown]
# **2.3**

# %% [markdown]
# **2.4**

# %% [markdown]
# **3.1**

# %% [markdown]
# **3.2** , **3.3**

# %% [markdown]
# **3.4**
