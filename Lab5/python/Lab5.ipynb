# %% [markdown]
# # Digital Signal Processing
#
# ### MsCV - ViBOT - MAIA

# %%
# %matplotlib inline
# %pprint off

# To make some nice plot
import matplotlib.pyplot as plt
# To play with arrays
import numpy as np
import scipy as sp
from skimage import io

from skimage import color
from skimage import img_as_float
from matplotlib import cm
from scipy.stats import norm
from skimage import exposure
from skimage import filters
from skimage.filters import rank
from skimage import transform
from skimage import img_as_ubyte

from scipy import signal
from scipy.io import wavfile
from scipy import fftpack
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# ## 2D - Discrete Fourier Transform
# **1.1** Consider a syntetic image as following:

# %%
# Create a synthetic image
img = np.zeros((301,301))
# Draw a rectangle inside
img[100:200, 140:160] = 255

plt.figure()
plt.imshow(img)

# %% [markdown]
# **1.2** We can compute the FFT as follows:

# %%
# Compute the DFT
img_freq = np.fft.fftshift(np.fft.fft2(img))

# We can show the magnitude and the phase
# Two subplots, the axes array is 1-d
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img_freq)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img_freq))
ax2.set_title('Phase')

# %% [markdown]
# **1.3** Compute the FFT of translated, rotated and other verisons of the synthetic image and illustrate the magnitude and phase of the frequency response.
#
# Discuss your observations

# %%
# Create a synthetic image
img = np.zeros((301,301))
# Draw a rectangle inside
img[100:200, 140:160] = 255

# Create a synthetic image
img_trans = np.zeros((301,301))
# Draw a rectangle inside
img_trans[150:250, 160:180] = 255

img_rot = transform.rotate(img, 45)

# Create a synthetic image
img2 = np.zeros((301,301))
# Draw a rectangle inside
img2[20:120, 140:160] = 255
img2[180:280, 140:160] = 255


# Create a synthetic image
img3 = np.zeros((301,301))
# Draw a rectangle inside
img3[100:200, 145:155] = 255

plt.figure
plt.subplot(121)
plt.imshow(img)
plt.title('First image')




plt.subplot(122)
plt.imshow(img_trans)
plt.title('Translated image')
plt.show()

# f, (ax1, ax2) = plt.subplots(1, 2)
# ax1.imshow(exposure.adjust_log(np.abs(img_freq)))
# ax1.set_title('Magnitude')
# ax2.imshow(np.angle(img_freq))
# ax2.set_title('Phase')


plt.figure()
plt.subplot(121)
plt.imshow(img_rot)
plt.title('Rotated image')

plt.subplot(122)
plt.imshow(img2)
plt.title('Double image')
plt.show()

plt.figure
plt.subplot(121)
plt.imshow(img3)
plt.title('Smaller object')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img_freq)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img_freq))
ax2.set_title('Phase')

img_trans_ = np.fft.fftshift(np.fft.fft2(img_trans))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img_trans_)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img_trans_))
ax2.set_title('Phase')

img_rot_ = np.fft.fftshift(np.fft.fft2(img_rot))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img_rot_)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img_rot_))
ax2.set_title('Phase')


img2_ = np.fft.fftshift(np.fft.fft2(img2))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img2_)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img2_))
ax2.set_title('Phase')


img3_ = np.fft.fftshift(np.fft.fft2(img3))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img3_)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img3_))
ax2.set_title('Phase')

# %%
# For different images with respect to rotating, translation and doubling

# Create a synthetic image
img = np.zeros((301,301))
# Draw a rectangle inside
img[50:150, 40:100] = 255

# Create a synthetic image
img_trans = np.zeros((301,301))
# Draw a rectangle inside
img_trans[150:200, 160:200] = 255

img_rot = transform.rotate(img, 75)

# Create a synthetic image
img2 = np.zeros((301,301))
# Draw a rectangle inside
img2[20:120, 140:160] = 255
img2[180:280, 160:180] = 255


# Create a synthetic image
img3 = np.zeros((301,301))
# Draw a rectangle inside
img3[100:200, 145:155] = 255

plt.figure
plt.subplot(121)
plt.imshow(img)
plt.title('First image')




plt.subplot(122)
plt.imshow(img_trans)
plt.title('Translated image')
plt.show()

# f, (ax1, ax2) = plt.subplots(1, 2)
# ax1.imshow(exposure.adjust_log(np.abs(img_freq)))
# ax1.set_title('Magnitude')
# ax2.imshow(np.angle(img_freq))
# ax2.set_title('Phase')


plt.figure()
plt.subplot(121)
plt.imshow(img_rot)
plt.title('Rotated image')

plt.subplot(122)
plt.imshow(img2)
plt.title('Double image')
plt.show()

plt.figure
plt.subplot(121)
plt.imshow(img3)
plt.title('Smaller object')
plt.show()


f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img_freq)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img_freq))
ax2.set_title('Phase')

img_trans_ = np.fft.fftshift(np.fft.fft2(img_trans))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img_trans_)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img_trans_))
ax2.set_title('Phase')

img_rot_ = np.fft.fftshift(np.fft.fft2(img_rot))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img_rot_)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img_rot_))
ax2.set_title('Phase')


img2_ = np.fft.fftshift(np.fft.fft2(img2))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img2_)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img2_))
ax2.set_title('Phase')


img3_ = np.fft.fftshift(np.fft.fft2(img3))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(img3_)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img3_))
ax2.set_title('Phase')

# %% [markdown]
# **1.4** Lets consider another synthetic image as follows, compute the phase and the magnitude of the followig image and display the normalized center frequency

# %%
N = 64
Img = np.zeros((N,N))
# Length of the signal
T = 1. 
# Sampling period 
Ts = T/N 
Fs = 1./Ts
df = Fs/N
tem = np.ones((8,16))
Img[N/8:N/4, N/4:N/2] = tem 
Img[0:N/4,N/2:] = Img[0:N/4, :N/2]
# Img[N/4:N/2,:] = Img[0:N/4 ,:]
# Img[N/2:,:] = Img[0:N/2,:]

plt.figure
io.imshow(Img)
plt.show()

# %%
N = 64
Img = np.zeros((N,N))
# Length of the signal
T = 1. 
# Sampling period 
Ts = T/N 
Fs = 1./Ts
df = Fs/N
tem = np.ones((8,16))
Img[N/8:N/4, N/4:N/2] = tem 
Img[0:N/4,N/2:] = Img[0:N/4, :N/2]
Img[N/4:N/2,:] = Img[0:N/4 ,:]
Img[N/2:,:] = Img[0:N/2,:]

img_freq = np.fft.fftshift(np.fft.fft2(Img))

#normalize fft

img_freq= img_freq/(N*N)
    


f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(np.abs(img_freq))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(img_freq))
ax2.set_title('Phase')

# plt.figure
# plt.imshow(np.abs(img_freq), cmap = cm.gray )
# plt.title('Magnitude of the image')
# plt.show()

# plt.figure
# plt.imshow(np.angle(img_freq), cmap = cm.gray )
# plt.title('phase of the image')
# plt.show()

# print

# %% [markdown]
# **1.5** Plot $|I_{f}(u,0)|$ and $|I_{f}(0,v)|$ with the corrrect frequency range.
#
# Discuss your observations.

# %%
hf = 0
vf = 0

hf = img_freq[N/2,:]
t = np.arange (-N/2,N/2,1)

plt.figure
plt.plot(t, np.abs(hf))
plt.title('Horizontal frequency')
plt.show()

vf = img_freq[:,N/2]
plt.figure
plt.plot(t, np.abs(vf))
plt.title('Vertical frequency')
plt.show()

# %% [markdown]
# **1.6** Load the `lena` image, and show its phase and its magnitude, then reconstruct the image using either frequency or phase.

# %%
import os, os.path
from skimage import color  
from scipy import misc, ndimage

Path = '../images/'
image_name ='lena-grey.bmp'
lena_im = io.imread(Path.__add__(image_name))
lena_im = img_as_float(lena_im)

plt.figure()
plt.imshow(lena_im, cmap=plt.cm.gray)
plt.imshow(lena_im)

image_name = np.fft.fftshift(np.fft.fft2(lena_im))
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exposure.adjust_log(np.abs(image_name)))
ax1.set_title('Magnitude')
ax2.imshow(np.angle(image_name))
ax2.set_title('Phase')

# image_name1 = np.fft.fftshift(np.fft.ifftn(lena_im))
# #mag_freq*np.exp(1j * ang_freq)
# f, (ax1, ax2) = plt.subplots(1, 2)
# ax1.imshow(exposure.adjust_log(np.abs(image_name1)))
# ax1.set_title('Magnitude')
# ax2.imshow(np.angle(image_name1))
# ax2.set_title('Phase')


img_lena_reconstructed = np.fft.ifft2(image_name)
img_lena_reconstructed_magn = np.fft.ifft2(np.abs(image_name))
img_lena_reconstructed_phase = np.fft.ifft2(200*np.exp(1j*np.angle(image_name)))

f, (ax0, ax1, ax2) = plt.subplots(1, 3, figsize=(15,4))
ax0.imshow(np.real(img_lena_reconstructed), cmap='gray')
ax0.set_title('Reconstructed with both')

# ax1.imshow(exposure.adjust_log(np.real(img_lena_reconstructed_magn)), cmap='gray')
# ax1.set_title('Reconstructed with magnitude')
# ax2.imshow(np.real(img_lena_reconstructed_phase), cmap='gray')
# ax2.set_title('Reconstructed with phase')

# %% [markdown]
# **1.7** Apply the sobel filter only in vertical direction to `lena` image in the frequency domain.

# %% [markdown]
# ### Filtering in Frequency domain
#
# In order to build a frequency filter $H(u,v)$ from its spatial counterpart $h(x,y)$, we need to:
#
# 1. Build a zero padded spatial filter $h_p(x,y)$
# 1. Shift $h_p(x,y)$ by $(-1)^{x+y}$
# 1. Compute the DFT to obtain $H(u,v)$
# 1. Shift $H(u,v)$ by $(-1)^{x+y}$
#
# In order to aboid the wraparound error, the image need to be zero padded
#
# In order to perform the filtering, we need to:
#
# 1. Find the padded image size
# 1. Pad the image
# 1. Convert the spatial filter to frequency filter
# 1. Compute the DFT of the image with additional shift
# 1. Apply the multiplication in the Fourier space
# 1. Compute the inverse Fourier transform
# 1. Crop the image at its original size

# %%
img_lena = img_as_float(io.imread('../images/lena-grey.bmp'))

hp = np.zeros((img_lena.shape[0]*2, img_lena.shape[1]*2))

#Add sobel operator
sobel_vertical = np.array([[1, 0, -1],
                           [2, 0, -2],
                           [1, 0, -1]])

hp[0:3, 0:3] = sobel_vertical

#Shift to center frequencies
for x in range(hp.shape[0]):
    for y in range(hp.shape[1]):
        hp[x, y] *= np.power(-1, x+y)
        
H = np.fft.fft2(hp)

#Shift to uncenter frequencies
for x in range(H.shape[0]):
    for y in range(H.shape[1]):
        H[x, y] *= np.power(-1, x+y)
        
#Build Padded image
img_lena_padded = np.zeros((img_lena.shape[0]*2, img_lena.shape[1]*2))
img_lena_padded[0:img_lena.shape[0], 0:img_lena.shape[1]] = img_lena

#Compute FFT of lena
img_lena_pad_freq = np.fft.fftshift(np.fft.fft2(img_lena_padded))

img_lena_filtered_freq = np.multiply(img_lena_pad_freq, H)

img_lena_filtered_freq = np.fft.ifft2(np.fft.fftshift(img_lena_filtered_freq))

img_lena_filtered_freq = img_lena_filtered_freq[img_lena.shape[0]:, img_lena.shape[1]:]

img_lena_sobel_v = filters.sobel_v(img_lena)


f, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,5))
ax0.imshow(np.real(img_lena_filtered_freq), cmap='gray')
ax0.set_title('Filtered in Frequency')
ax1.imshow(img_lena_sobel_v, cmap='gray')
ax1.set_title('Filtered with Skimage')
